# %% [markdown]
# SOAL 1

# %% [markdown]
# MEAN

# %%
# Inisialisasi dataset
data = [100.5, 99.7, 101, 101.3, 99.9, 98.9, 165, 102.2, 98.7, 102.9, 100]
print(f"Data: {data}")

# Jumlah nilai dalam dataset 
jumlah_nilai = sum(data)
print(f"Jumlah semua nilai: {jumlah_nilai}")

# Jumlah total data dalam dataset 
jumlah_total_data = len(data)
print(f"Jumlah total data: {jumlah_total_data}")

# Jumlah semua nilai dalam dataset 
mean_value = jumlah_nilai / jumlah_total_data
print(f"Mean: {mean_value}")

import matplotlib.pyplot as plt

# Create a histogram
plt.hist(data, bins=30, edgecolor='black', alpha=0.5, color='blue')

# Add a vertical line at the mean
plt.axvline(x=mean_value, color='red', linestyle='dashed', linewidth=1, label=f'Mean = {mean_value:.2f}')

# Add labels and title
plt.xlabel('Jumlah')
plt.ylabel('Tinggi (cm)')
plt.title('Mean')

# Add legend
plt.legend()

# Show the plot
plt.show()
# Out:
# Data: [100.5, 99.7, 101, 101.3, 99.9, 98.9, 165, 102.2, 98.7, 102.9, 100]
# Jumlah semua nilai: 1170.1000000000001
# Jumlah total data: 11
# Mean: 106.37272727272729

# %% [markdown]
# MEDIAN

# %%
# Inisialisasi dataset
data = [100.5, 99.7, 101, 101.3, 99.9, 98.9, 165, 102.2, 98.7, 102.9, 100]
print(f"Data: {data}")

# Mengurutkan data dari terkecil hingga terbesar
sorted_data = sorted(data)
print(f"Data berurut: {sorted_data}")

# Jumlah total data dalam dataset 
n = len(sorted_data)
print(f"Jumlah total data: {n}")

index_tengah = n//2 # double slash // is used for floor division

# Jika jumlah data genap, median adalah rata-rata dari dua nilai tengah 
if n % 2 == 0:
    print(f"Jumlah total data Genap")
    median1 = sorted_data[index_tengah]
    median2 = sorted_data[index_tengah - 1]
    print(f"Nilai tengah: {median1} {median2}")
    median_value = (median1 + median2) / 2
    
# Jika jumlah data ganjil, median adalah nilai tengah
else:
    print(f"Jumlah total data Ganjil")
    median_value = sorted_data[index_tengah]
    print(f"Nilai tengah: {median_value}")

print(f"Median: {median_value}")

import matplotlib.pyplot as plt

# Create a histogram
plt.hist(data, bins=30, edgecolor='black', alpha=0.5, color='blue')

# Add a vertical line at the mean
plt.axvline(x=median_value, color='red', linestyle='dashed', linewidth=1, label=f'Median = {median_value:.2f}')

# Add labels and title
plt.xlabel('Tinggi (cm)')
plt.ylabel('Jumlah')
plt.title('Median')

# Add legend
plt.legend()

# Show the plot
plt.show()
# Out:
# Data: [100.5, 99.7, 101, 101.3, 99.9, 98.9, 165, 102.2, 98.7, 102.9, 100]
# Data berurut: [98.7, 98.9, 99.7, 99.9, 100, 100.5, 101, 101.3, 102.2, 102.9, 165]
# Jumlah total data: 11
# Jumlah total data Ganjil
# Nilai tengah: 100.5
# Median: 100.5

# %% [markdown]
# MODUS

# %%
# Import library Counter untuk menghitung modus
from collections import Counter

# Inisialisasi dataset
data = [100.5, 99.7, 101, 101.3, 99.9, 98.9, 165, 102.2, 98.7, 102.9, 100]
print(f"Data: {data}")

counter = Counter(data)
mode_data = dict(counter) # ubah ke tipe data dictionary
max_counter = max(list(counter.values())) # mencari data yang memiliki counter paling banyak
print(f"Max Counter: {max_counter}")

mode_value = []
for k, v in mode_data.items():
    print(f"{k} muncul {v} kali")
    if v == max(list(counter.values())):
        mode_value.append(k)
    
print(f"Modus: {mode_value}")

import matplotlib.pyplot as plt

# Create a histogram
plt.hist(data, bins=30, edgecolor='black', alpha=0.5, color='green')

# Add a vertical line at the mean
plt.axvline(x=mode_value[0], color='red', linestyle='dashed', linewidth=1, label=f'Modus 1 = {mode_value[0]:.2f}')
plt.axvline(x=mode_value[1], color='blue', linestyle='dashed', linewidth=1, label=f'Modus 2 = {mode_value[1]:.2f}')
plt.axvline(x=mode_value[2], color='blue', linestyle='dashed', linewidth=1, label=f'Modus 3 = {mode_value[2]:.2f}')
plt.axvline(x=mode_value[3], color='blue', linestyle='dashed', linewidth=1, label=f'Modus 4 = {mode_value[3]:.2f}')
plt.axvline(x=mode_value[4], color='blue', linestyle='dashed', linewidth=1, label=f'Modus 5 = {mode_value[4]:.2f}')
plt.axvline(x=mode_value[5], color='blue', linestyle='dashed', linewidth=1, label=f'Modus 6 = {mode_value[5]:.2f}')
plt.axvline(x=mode_value[6], color='blue', linestyle='dashed', linewidth=1, label=f'Modus 7 = {mode_value[6]:.2f}')
plt.axvline(x=mode_value[7], color='blue', linestyle='dashed', linewidth=1, label=f'Modus 8 = {mode_value[7]:.2f}')
plt.axvline(x=mode_value[8], color='blue', linestyle='dashed', linewidth=1, label=f'Modus 9 = {mode_value[8]:.2f}')
plt.axvline(x=mode_value[9], color='blue', linestyle='dashed', linewidth=1, label=f'Modus 10 = {mode_value[9]:.2f}')

# Add labels and title
plt.xlabel('Tinggi (cm)')
plt.ylabel('Jumlah')
plt.title('Modus')

# Add legend
plt.legend()

# Show the plot
plt.show()
# Out:
# Data: [100.5, 99.7, 101, 101.3, 99.9, 98.9, 165, 102.2, 98.7, 102.9, 100]
# Max Counter: 1
# 100.5 muncul 1 kali
# 99.7 muncul 1 kali
# 101 muncul 1 kali
# 101.3 muncul 1 kali
# 99.9 muncul 1 kali
# 98.9 muncul 1 kali
# 165 muncul 1 kali
# 102.2 muncul 1 kali
# 98.7 muncul 1 kali
# 102.9 muncul 1 kali
# 100 muncul 1 kali
# Modus: [100.5, 99.7, 101, 101.3, 99.9, 98.9, 165, 102.2, 98.7, 102.9, 100]

# %% [markdown]
# SOAL 2

# %% [markdown]
# MEAN

# %%
# Inisialisasi dataset
data = [95, 35, 50, 65, 70, 85, 25, 100, 80, 90, 45, 40, 35, 20, 75, 50, 40, 60, 80, 75]
print(f"Data: {data}")

# Jumlah nilai dalam dataset 
jumlah_nilai = sum(data)
print(f"Jumlah semua nilai: {jumlah_nilai}")

# Jumlah total data dalam dataset 
jumlah_total_data = len(data)
print(f"Jumlah total data: {jumlah_total_data}")

# Jumlah semua nilai dalam dataset 
mean_value = jumlah_nilai / jumlah_total_data
print(f"Mean: {mean_value}")

import matplotlib.pyplot as plt

# Create a histogram
plt.hist(data, bins=30, edgecolor='black', alpha=0.5, color='blue')

# Add a vertical line at the mean
plt.axvline(x=mean_value, color='red', linestyle='dashed', linewidth=1, label=f'Mean = {mean_value:.2f}')

# Add labels and title
plt.xlabel('Nilai')
plt.ylabel('Jumlah')
plt.title('Mean')

# Add legend
plt.legend()

# Show the plot
plt.show()
# Out:
# Data: [95, 35, 50, 65, 70, 85, 25, 100, 80, 90, 45, 40, 35, 20, 75, 50, 40, 60, 80, 75]
# Jumlah semua nilai: 1215
# Jumlah total data: 20
# Mean: 60.75

# %% [markdown]
# MODUS

# %%
# Import library Counter untuk menghitung modus
from collections import Counter

# Inisialisasi dataset
data = [95, 35, 50, 65, 70, 85, 25, 100, 80, 90, 45, 40, 35, 20, 75, 50, 40, 60, 80, 75]
print(f"Data: {data}")

counter = Counter(data)
mode_data = dict(counter) # ubah ke tipe data dictionary
max_counter = max(list(counter.values())) # mencari data yang memiliki counter paling banyak
print(f"Max Counter: {max_counter}")

mode_value = []
for k, v in mode_data.items():
    print(f"{k} muncul {v} kali")
    if v == max(list(counter.values())):
        mode_value.append(k)
    
print(f"Mode: {mode_value}")

import matplotlib.pyplot as plt

# Create a histogram
plt.hist(data, bins=30, edgecolor='black', alpha=0.5, color='green')

# Add a vertical line at the mean
plt.axvline(x=mode_value[0], color='red', linestyle='dashed', linewidth=1, label=f'Modus 1 = {mode_value[0]:.2f}')
plt.axvline(x=mode_value[1], color='blue', linestyle='dashed', linewidth=1, label=f'Modus 2 = {mode_value[1]:.2f}')
plt.axvline(x=mode_value[2], color='blue', linestyle='dashed', linewidth=1, label=f'Modus 3 = {mode_value[2]:.2f}')
plt.axvline(x=mode_value[3], color='blue', linestyle='dashed', linewidth=1, label=f'Modus 4 = {mode_value[3]:.2f}')
plt.axvline(x=mode_value[4], color='blue', linestyle='dashed', linewidth=1, label=f'Modus 5 = {mode_value[4]:.2f}')

# Add labels and title
plt.xlabel('Nilai')
plt.ylabel('Jumlah')
plt.title('Modus')

# Add legend
plt.legend()

# Show the plot
plt.show()
# Out:
# Data: [95, 35, 50, 65, 70, 85, 25, 100, 80, 90, 45, 40, 35, 20, 75, 50, 40, 60, 80, 75]
# Max Counter: 2
# 95 muncul 1 kali
# 35 muncul 2 kali
# 50 muncul 2 kali
# 65 muncul 1 kali
# 70 muncul 1 kali
# 85 muncul 1 kali
# 25 muncul 1 kali
# 100 muncul 1 kali
# 80 muncul 2 kali
# 90 muncul 1 kali
# 45 muncul 1 kali
# 40 muncul 2 kali
# 20 muncul 1 kali
# 75 muncul 2 kali
# 60 muncul 1 kali
# Mode: [35, 50, 80, 40, 75]

# %% [markdown]
# MEDIAN

# %%
# Inisialisasi dataset
data = [95, 35, 50, 65, 70, 85, 25, 100, 80, 90, 45, 40, 35, 20, 75, 50, 40, 60, 80, 75]
print(f"Data: {data}")

# Mengurutkan data dari terkecil hingga terbesar
sorted_data = sorted(data)
print(f"Data berurut: {sorted_data}")

# Jumlah total data dalam dataset 
n = len(sorted_data)
print(f"Jumlah total data: {n}")

index_tengah = n//2 # double slash // is used for floor division

# Jika jumlah data genap, median adalah rata-rata dari dua nilai tengah 
if n % 2 == 0:
    print(f"Jumlah total data Genap")
    median1 = sorted_data[index_tengah]
    median2 = sorted_data[index_tengah - 1]
    print(f"Nilai tengah: {median1} {median2}")
    median_value = (median1 + median2) / 2
    
# Jika jumlah data ganjil, median adalah nilai tengah
else:
    print(f"Jumlah total data Ganjil")
    median_value = sorted_data[index_tengah]
    print(f"Nilai tengah: {median_value}")

print(f"Median: {median_value}")

import matplotlib.pyplot as plt

# Create a histogram
plt.hist(data, bins=30, edgecolor='black', alpha=0.5, color='blue')

# Add a vertical line at the mean
plt.axvline(x=median_value, color='red', linestyle='dashed', linewidth=1, label=f'Median = {median_value:.2f}')

# Add labels and title
plt.xlabel('Nilai')
plt.ylabel('Jumlah')
plt.title('Median')

# Add legend
plt.legend()

# Show the plot
plt.show()
# Out:
# Data: [95, 35, 50, 65, 70, 85, 25, 100, 80, 90, 45, 40, 35, 20, 75, 50, 40, 60, 80, 75]
# Data berurut: [20, 25, 35, 35, 40, 40, 45, 50, 50, 60, 65, 70, 75, 75, 80, 80, 85, 90, 95, 100]
# Jumlah total data: 20
# Jumlah total data Genap
# Nilai tengah: 65 60
# Median: 62.5
